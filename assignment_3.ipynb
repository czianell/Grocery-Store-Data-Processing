# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.figure
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, *, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
items = pd.read_json("./grocery-items.json")
display(items)
# Out:
#      item_name  item_price  item_sku  num_of_purchases
# 0   Fresh Milk        2.58       100                20
# 1     Oat Milk        3.99       101                15
# 2  Almond Milk        3.25       102                 7

# %%
"""Calculate the total sales"""
def calc_total_sales(df):
    df['total_sales'] = df['item_price'] * df['num_of_purchases']
    return df

# %%
"""Find the most purchased item"""
def most_popular(df):
    highest_num = df['num_of_purchases'].max()
    summary = "The most popular item made", highest_num, "sales."
    
    return highest_num

# %%
print("The most popular item made", most_popular(items), "sales.")
# Out:
# The most popular item made 20 sales.

# %%
## Total Sales
total_sales = calc_total_sales(items)

# %%
"""Create a chart with each item and their total sales"""
plt.figure(figsize=(8, 6))
plt.bar(df_with_sales['item_name'], df_with_sales['total_sales'], color='skyblue')
plt.xlabel('Items')
plt.ylabel('Total Sales')
plt.title('Total Sales of Grocery Store Items')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
